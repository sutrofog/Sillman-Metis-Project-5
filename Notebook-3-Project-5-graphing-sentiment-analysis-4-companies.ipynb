# %%
import pickle
with open('df_4_companies_prep_tb_sentiment.pickle', 'rb') as read_file:
    df_4_companies_prep=pickle.load(read_file)
df_4_companies_prep.head(1)
# Out:
#    article_date                                  article_link-href  \
# 0  Apr 01, 2019  https://www.novartis.com/news/media-releases/n...
#
#                                        article_title ticker  \
# 0  Novartis adds clinical and preclinical anti-in...    NVS
#
#                                   article_text_clean  \
# 0  acquisition will give one clinical and two pre...
#
#                                   article_text_words  \
# 0  [acquisition, will, give, one, clinical, and, ...
#
#                                 article_words_nostop  \
# 0  [acquisition, give, one, clinical, two, precli...
#
#                                    article_words_str  tb_Sent_Pol  \
# 0  ['acquisition', 'give', 'one', 'clinical', 'tw...     0.126201
#
#    tb_Sent_Subj
# 0      0.489756

# %%
import pandas as pd
import numpy as np
import re
import string
from pprint import pprint
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append("/Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages")

# %%
#I can drop a couple columns
df_4_companies_prep.drop(columns=['article_text_words', 'article_text_clean'], inplace=True)
df_4_companies_prep.head(1)
# Out:
#    article_date                                  article_link-href  \
# 0  Apr 01, 2019  https://www.novartis.com/news/media-releases/n...
#
#                                        article_title ticker  \
# 0  Novartis adds clinical and preclinical anti-in...    NVS
#
#                                 article_words_nostop  \
# 0  [acquisition, give, one, clinical, two, precli...
#
#                                    article_words_str  tb_Sent_Pol  \
# 0  ['acquisition', 'give', 'one', 'clinical', 'tw...     0.126201
#
#    tb_Sent_Subj
# 0      0.489756

# %%
import seaborn as sns

# %%
sns.scatterplot(x='article_date', y='tb_Sent_Pol',  hue='ticker', data=df_4_companies_prep)

# %%
#Maybe just look at Lilly for now? There is a wide variety of sentiment.

# %%
#drop the text columns, save to a csv, look for specific article dates in excel
df_4_companies_working_wsentiment=df_4_companies_prep.drop(columns=['article_words_nostop', 'article_words_str'])
df_4_companies_working_wsentiment.head(1)
# Out:
#    article_date                                  article_link-href  \
# 0  Apr 01, 2019  https://www.novartis.com/news/media-releases/n...
#
#                                        article_title ticker  tb_Sent_Pol  \
# 0  Novartis adds clinical and preclinical anti-in...    NVS     0.126201
#
#    tb_Sent_Subj
# 0      0.489756

# %%
df_4_companies_working_wsentiment.to_csv('df_4_companies_working_wsentiment.csv')
